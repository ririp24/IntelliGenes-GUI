# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.cluster import OPTICS

# %%
X = pd.read_csv('data/Full_X.csv')
X.drop(columns=X.columns[0], axis=1, inplace=True)

# %%
xt = X.T
xt['Marker'] = xt.index
xt = pd.melt(xt, id_vars=['Marker'])
# xt['Cluster'] = clusters[xt['variable']]
xt.head()
# Out:
#             Marker variable   value
# 0  ENSG00000215021        0   23.74
# 1  ENSG00000215845        0    0.00
# 2  ENSG00000227097        0  448.15
# 3  ENSG00000231389        0   38.07
# 4  ENSG00000233276        0  455.51

# %%
clusterer = OPTICS(min_samples = 0.1)
clusters = np.array(clusterer.fit_predict(X))

# %%
clusters[[1, 5, 7]]
# Out:
# array([1, 1, 1])

# %%
sum(clusters[list(xt['variable'])])
# Out:
# 19

# %%
xt['Cluster'] = clusters[list(xt['variable'])]

# %%
px.scatter(xt, x=xt.Marker, y=xt.value, color=xt.Cluster)

# %%
X_low = np.loadtxt('data/X_Low.csv', delimiter=',')

# %%
plt.scatter(X_low[:, 0], X_low[:, 1], c=y, cmap='Spectral')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.scatter(X_low[:, 0], X_low[:, 1], c=y, cmap='Spectral')
#
# NameError: name 'y' is not defined

# %%
np.random.seed()

# Define the number of samples and features
num_samples = 5
num_features = 5

# Generate random data
data = np.random.randint(1, 10, (5, 5))

# Create a DataFrame
df = pd.DataFrame(data, columns=[f'feature_{i+1}' for i in range(num_features)])

# Display the DataFrame
print(df)
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5
# 0          9          8          2          7          3
# 1          6          7          8          5          2
# 2          5          4          8          8          1
# 3          5          9          5          3          2
# 4          8          6          6          2          4

# %%
new_samples = []
test_features = ["feature_1", "feature_2"]
medians = df.median()
feature1_range = np.linspace(df[test_features[0]].min(), df[test_features[0]].max(), 10)
feature2_range = np.linspace(df[test_features[1]].min(), df[test_features[1]].max(), 10)
for val1 in feature1_range:
    for val2 in feature2_range:
        sample = medians.copy()
        sample[test_features[0]] = val1
        sample[test_features[1]] = val2
        new_samples.append(sample)
new_df = pd.DataFrame(new_samples)
new_df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5
# 0        5.0   4.000000        6.0        5.0        2.0
# 1        5.0   4.555556        6.0        5.0        2.0
# 2        5.0   5.111111        6.0        5.0        2.0
# 3        5.0   5.666667        6.0        5.0        2.0
# 4        5.0   6.222222        6.0        5.0        2.0

# %%
fig = plt.figure()
ax = plt.gca()
ax = fig.add_subplot(projection='3d')
ax.scatter(new_df["feature_1"], new_df["feature_2"], range(100), c=range(100), cmap=cm.viridis)
ax.plot_trisurf(new_df["feature_1"], new_df["feature_2"], range(100), cmap=cm.viridis)
plt.pause(10)

# %%
print(new_df.columns)
# Out:
# Index(['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5'], dtype='object')

# %%
# %matplotlib
# Out:
# Using matplotlib backend: QtAgg

# %%
fig, ax = plt.subplots()

# %%
ln, = ax.plot(range(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ln, = ax.plot(range(5))
#
# TypeError: Axes3D.plot() missing 1 required positional argument: 'ys'

# %%
plt.ioff()

# %%
plt.ion()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()


x = np.linspace(0, 2*np.pi, 100)
y = np.sin(3*x)
ax.plot(x, y)

# %%
import re, seaborn as sns
import numpy as np

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# generate data
n = 200
x = np.random.uniform(1, 20, size=n)
y = np.random.uniform(1, 100, size=n)
z = np.random.uniform(1, 100, size=n)

# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=x, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)

# save
plt.savefig("scatter_hue", bbox_inches='tight')

# %%
x = pd.read_csv('data/x.csv')
x_t = pd.read_csv('data/.csv')
X = pd.concat([x, x_t])
# x = x.drop(columns=x.columns[0], axis=1)

# %%
x_low = pd.read_csv('X_Low_Final.csv', header=None)

# %%
x_low
# Out:
#             0         1         2
# 0  -10.300066 -1.248624 -0.107992
# 1   11.044617 -1.997504  2.627960
# 2   -8.810309  0.523197 -1.008167
# 3    9.593605  0.482767 -0.307858
# 4    8.354760  0.003518  0.202949
# ..        ...       ...       ...
# 67  11.138053 -1.251113  1.676699
# 68  -7.642858  0.430130  0.497873
# 69   9.213174  0.196168  0.124438
# 70  -7.311966  0.348272  0.325293
# 71 -10.368231 -0.818039 -0.193031
#
# [72 rows x 3 columns]

# %%
np.save('what.npy', randomarr)
